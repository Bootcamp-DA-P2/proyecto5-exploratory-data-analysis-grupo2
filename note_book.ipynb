# %% [markdown]
# # **Limpieza y análisis exploratorio del DataFrame 1: actividad de clientes**

# %% [markdown]
# ## **1. Carga de datos**

# %%
import os
print(f"Tu Python está trabajando en: {os.getcwd()}")
# Out:
# Tu Python está trabajando en: c:\Users\felix\Documents\bootcamp\mes 2\proyecto5-exploratory-data-analysis-grupo2

# %%
# Importación de librerías necesarias para análisis y visualización de datos
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Al estar en la raíz, la carpeta 'data' está directamente ahí
datos_ruta = "./data/all-states-history.csv"

# Carga del dataset
df_raw = pd.read_csv(datos_ruta)
df_raw.head()
# Out:
#          date state    death  deathConfirmed  deathIncrease  deathProbable  \
# 0  2021-03-07    AK    305.0             NaN              0            NaN
# 1  2021-03-07    AL  10148.0          7963.0             -1         2185.0
# 2  2021-03-07    AR   5319.0          4308.0             22         1011.0
# 3  2021-03-07    AS      0.0             NaN              0            NaN
# 4  2021-03-07    AZ  16328.0         14403.0              5         1925.0
#
#    hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0        1293.0                  1293.0                   33.0
# 1       45976.0                 45976.0                  494.0
# 2       14926.0                 14926.0                  335.0
# 3           NaN                     NaN                    NaN
# 4       57907.0                 57907.0                  963.0
#
#    hospitalizedIncrease  ...  totalTestResults  totalTestResultsIncrease  \
# ...
